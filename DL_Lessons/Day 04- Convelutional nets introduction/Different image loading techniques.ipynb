# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=plt.imread(r'D:\Data_Science\Projects\Identify_Dog_Breed\Dataset\Affenpinscher-puppy.jpg')
plt.imshow(img)
print(img.shape)
# Out:
# (486, 729, 3)

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img



img1 = load_img(r'C:\Users\Pasan Devin\Desktop\DL_Workshop\Deep Learning 10 Days Workshop\Day 06\My_Practice\data\IMG\right_2021_01_28_02_58_40_866.jpg')  # this is a PIL image

x = img_to_array(img1)

print(x.shape)
# Out:
# (160, 320, 3)

# %%
img2=cv2.imread(r'C:\Users\Pasan Devin\Desktop\DL_Workshop\Deep Learning 10 Days Workshop\Day 06\My_Practice\data\IMG\right_2021_01_28_02_58_40_866.jpg')

print(img2.shape)
# Out:
# (160, 320, 3)

# %%
a=[]
print(a.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-66667020738b> in <module>
#       1 a=[]
# ----> 2 print(a.shape)
#
# AttributeError: 'list' object has no attribute 'shape'
