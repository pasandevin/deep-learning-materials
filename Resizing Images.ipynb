# %%
import cv2
img_size=244
img=cv2.imread(r'C:\Users\Pasan Devin\Desktop\New folder (2)\myData\1\00069_00020.jpg')
resized=cv2.resize(img,(img_size,img_size))

# %%
import matplotlib.pyplot as plt
plt.imshow(resized)

# %%
resized.shape
# Out:
# (244, 244, 3)

# %%
import pickle
import numpy as np
objects = []
with (open(r'C:\Users\Pasan Devin\Desktop\New folder (3)/test.p', "rb")) as openfile:
    while True:
        try:
            objects.append(pickle.load(openfile))
        except EOFError:
            break
plot= np.array(objects)

# %%
print(plot.shape)
# Out:
# (1,)

# %%
plt.imshow(plot[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-1e00b00ca0c1> in <module>
# ----> 1 plt.imshow(plot[0])
#
# D:\Anaconda_Environment\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# D:\Anaconda_Environment\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...
