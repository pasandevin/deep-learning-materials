# %% [markdown]
# <img src="https://user-images.githubusercontent.com/26833433/98702494-b71c4e80-237a-11eb-87ed-17fcd6b3f066.jpg">
#
# This notebook was written by Ultralytics LLC, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://www.ultralytics.com.

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.8.1+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# !unzip -q ../cat_and_dog_train_data.zip -d ../

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases).

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source ../dog.mp4
# Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='../dog.mp4', update=False, view_img=False, weights=['runs/train/exp/weights/last.pt'])
# YOLOv5 🚀 v4.0-189-gc03d590 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPS
# video 1/1 (1/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.011s)
# video 1/1 (2/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (3/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (4/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (5/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (6/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (7/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.013s)
# video 1/1 (8/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (9/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (10/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (11/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (12/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (13/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.013s)
# video 1/1 (14/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (15/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (16/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (17/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.011s)
# video 1/1 (18/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.013s)
# video 1/1 (19/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (20/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (21/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.011s)
# video 1/1 (22/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (23/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (24/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (25/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (26/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (27/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (28/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (29/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (30/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (31/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (32/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (33/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (34/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (35/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.013s)
# video 1/1 (36/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (37/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (38/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (39/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (40/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (41/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (42/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (43/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (44/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (45/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.010s)
# video 1/1 (46/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (47/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.013s)
# video 1/1 (48/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (49/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (50/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (51/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (52/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (53/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (54/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (55/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (56/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.015s)
# video 1/1 (57/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (58/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (59/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (60/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (61/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (62/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (63/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (64/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (65/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.013s)
# video 1/1 (66/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (67/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (68/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (69/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (70/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (71/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (72/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (73/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (74/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (75/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (76/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (77/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (78/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (79/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.013s)
# video 1/1 (80/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (81/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (82/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (83/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (84/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (85/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (86/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (87/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (88/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (89/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (90/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (91/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (92/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (93/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (94/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (95/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.013s)
# video 1/1 (96/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (97/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.014s)
# video 1/1 (98/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (99/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (100/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (101/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (102/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (103/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (104/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (105/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (106/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (107/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (108/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (109/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (110/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.013s)
# video 1/1 (111/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (112/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (113/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (114/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (115/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (116/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (117/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (118/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (119/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.013s)
# video 1/1 (120/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (121/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (122/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (123/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (124/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (125/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.010s)
# video 1/1 (126/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (127/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (128/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (129/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (130/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (131/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (132/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (133/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (134/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (135/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (136/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (137/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (138/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (139/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (140/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (141/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (142/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (143/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.010s)
# video 1/1 (144/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (145/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (146/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.013s)
# video 1/1 (147/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (148/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (149/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (150/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (151/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (152/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (153/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (154/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (155/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.013s)
# video 1/1 (156/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (157/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (158/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.011s)
# video 1/1 (159/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (160/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (161/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (162/509) /content/yolov5/../dog.mp4: 384x640 1 Dog, Done. (0.012s)
# video 1/1 (163/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (164/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.013s)
# video 1/1 (165/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (166/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (167/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (168/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (169/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (170/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (171/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.012s)
# video 1/1 (172/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (173/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (174/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (175/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (176/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (177/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (178/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.010s)
# video 1/1 (179/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# video 1/1 (180/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.011s)
# [h264 @ 0x562b0b89ad00] Invalid NAL unit size (65782 > 12785).
# [h264 @ 0x562b0b89ad00] Error splitting the input into NAL units.
# video 1/1 (181/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.009s)
# video 1/1 (182/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.009s)
# video 1/1 (183/509) /content/yolov5/../dog.mp4: 384x640 Done. (0.009s)
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfe9a75: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfe9d18: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfe9fbc: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfea260: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfea503: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfea7a7: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfeacee: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfeaf92: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfeb236: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfeb4d9: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfeb77d: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfeba21: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfebf68: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfec20c: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfec4af: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfec753: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfec9f7: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfecc9a: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfed1e2: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0xfed485: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0xfed729: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x118553b: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x11857de: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1185a82: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1185d26: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1185fc9: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x118626d: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x11867b4: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1186a58: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1186cfc: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1186f9f: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1187243: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x11874e7: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1187a2e: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1187cd2: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1187f75: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1188219: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x11884bd: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1188760: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1188ca8: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1188f4b: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0x11891ef: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1315712: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x13159b5: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1315c59: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1315efd: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x13161a0: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1316444: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x131698b: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1316c2f: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1316ed3: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1317176: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x131741a: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x13176be: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1317c05: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1317ea9: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x131814c: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x13183f0: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1318694: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1318937: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1318e7f: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1319122: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0x13193c6: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145c747: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145c9ea: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145cc8e: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145cf32: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145d1d5: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145d479: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145d9c0: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145dc64: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145df08: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145e1ab: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145e44f: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145e6f3: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145ec3a: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145eede: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145f181: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145f425: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145f6c9: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145f96c: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x145feb4: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1460157: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0x14603fb: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x15759cf: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1575c72: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1575f16: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x15761ba: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x157645d: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1576701: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1576c48: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1576eec: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1577190: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1577433: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x15776d7: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x157797b: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1577ec2: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1578166: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1578409: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x15786ad: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1578951: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1578bf4: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x157913c: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x15793df: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0x1579683: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167bf6e: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167c211: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167c4b5: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167c759: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167c9fc: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167cca0: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167d1e7: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167d48b: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167d72f: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167d9d2: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167dc76: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167df1a: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167e461: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167e705: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167e9a8: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167ec4c: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167eef0: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167f193: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167f6db: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x167f97e: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0x167fc22: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17ee60a: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17ee8ad: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17eeb51: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17eedf5: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17ef098: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17ef33c: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17ef883: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17efb27: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17efdcb: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17f006e: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17f0312: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17f05b6: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17f0afd: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17f0da1: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17f1044: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17f12e8: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17f158c: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17f182f: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17f1d77: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x17f201a: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0x17f22be: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x19757eb: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1975a8e: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1975d32: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1975fd6: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1976279: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x197651d: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1976a64: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1976d08: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1976fac: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x197724f: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x19774f3: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1977797: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1977cde: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1977f82: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1978225: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x19784c9: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x197876d: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1978a10: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1978f58: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x19791fb: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0x197949f: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1aedcc4: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1aedf67: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1aee20b: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1aee4af: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1aee752: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1aee9f6: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1aeef3d: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1aef1e1: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1aef485: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1aef728: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1aef9cc: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1aefc70: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1af01b7: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1af045b: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1af06fe: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1af09a2: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1af0c46: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1af0ee9: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1af1431: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1af16d4: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0x1af1978: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6af30: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6b1d3: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6b477: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6b71b: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6b9be: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6bc62: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6c1a9: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6c44d: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6c6f1: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6c994: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6cc38: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6cedc: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6d423: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6d6c7: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6d96a: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6dc0e: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6deb2: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6e155: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6e69d: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1c6e940: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0x1c6ebe4: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e08211: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e084b4: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e08758: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e089fc: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e08c9f: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e08f43: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e0948a: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e0972e: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e099d2: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e09c75: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e09f19: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e0a1bd: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e0a704: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e0a9a8: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e0ac4b: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e0aeef: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e0b193: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e0b436: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e0b97e: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1e0bc21: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0x1e0bec5: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe36f3: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe3996: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe3c3a: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe3ede: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe4181: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe4425: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe496c: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe4c10: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe4eb4: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe5157: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe53fb: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe569f: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe5be6: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe5e8a: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe612d: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe63d1: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe6675: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe6918: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe6e60: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x1fe7103: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0x1fe73a7: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x2193f88: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x219422b: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x21944cf: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x2194773: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x2194a16: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x2194cba: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x2195201: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x21954a5: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x2195749: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x21959ec: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x2195c90: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x2195f34: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x219647b: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x219671f: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x21969c2: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x2196c66: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x2196f0a: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x21971ad: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x21976f5: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 1, offset 0x2197998: partial file
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x562a7be2e000] stream 0, offset 0x2197c3c: partial file
# Results saved to runs/detect/exp
# Done. (21.079s)

# %% [markdown]
# Results are saved to `runs/detect`. A full list of available inference sources:
# <img src="https://user-images.githubusercontent.com/26833433/98274798-2b7a7a80-1f94-11eb-91a4-70c73593e26b.jpg" width="900">

# %% [markdown]
# # 2. Test
# Test a model on [COCO](https://cocodataset.org/#home) val or test-dev dataset to evaluate trained accuracy. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be 1-2% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val2017
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip
# Out:
# HBox(children=(FloatProgress(value=0.0, max=819257867.0), HTML(value='')))

# %%
# Run YOLOv5x on COCO val2017
# !python test.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='./data/coco.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.65, name='exp', project='runs/test', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['yolov5x.pt'])
# YOLOv5 🚀 v4.0-137-g9b11f0c torch 1.8.0+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v4.0/yolov5x.pt to yolov5x.pt...
# 100% 168M/168M [00:02<00:00, 59.1MB/s]
#
# Fusing layers...
# Model Summary: 476 layers, 87730285 parameters, 0 gradients, 218.8 GFLOPS
# val: Scanning '../coco/val2017' for images and labels... 4952 found, 48 missing, 0 empty, 0 corrupted: 100% 5000/5000 [00:01<00:00, 3236.68it/s]
# val: New cache created: ../coco/val2017.cache
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 157/157 [01:20<00:00,  1.95it/s]
#                  all        5000       36335       0.749       0.619        0.68       0.486
# Speed: 5.3/1.7/6.9 ms inference/NMS/total per 640x640 image at batch-size 32
#
# Evaluating pycocotools mAP... saving runs/test/exp/yolov5x_predictions.json...
# loading annotations into memory...
# Done (t=0.43s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=5.10s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=88.52s).
# Accumulating evaluation results...
# DONE (t=17.17s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.501
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.687
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.544
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.338
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.548
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.637
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.680
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.729
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.826
# Results saved to runs/test/exp

# %% [markdown]
# ## COCO test-dev2017
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip # unzip labels
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f && rm $f  # 7GB,  41k images
# %mv ./test2017 ../coco/images  # move to /coco

# %%
# Run YOLOv5s on COCO test-dev2017 using --task test
# !python test.py --weights yolov5s.pt --data coco.yaml --task test

# %% [markdown]
# # 3. Train
#
# Download [COCO128](https://www.kaggle.com/ultralytics/coco128), a small 128-image tutorial dataset, start tensorboard and train YOLOv5s from a pretrained checkpoint for 3 epochs (note actual training is typically much longer, around **300-1000 epochs**, depending on your dataset).

# %%
# Download COCO128
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip
# Out:
# HBox(children=(FloatProgress(value=0.0, max=22091032.0), HTML(value='')))

# %% [markdown]
# Train a YOLOv5s model on [COCO128](https://www.kaggle.com/ultralytics/coco128) with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and **COCO, COCO128, and VOC datasets are downloaded automatically** on first use.
#
# All training results are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.

# %%
# Tensorboard (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases (optional)
# %pip install -q wandb  
# !wandb login  # use 'wandb disabled' or 'wandb enabled' to disable or enable

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 60 --data custom_data.yaml --weights yolov5s.pt --nosave --cache
# Out:
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v4.0-189-gc03d590 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=True, cfg='', data='./data/custom_data.yaml', device='', entity=None, epochs=60, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=True, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov5s.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# 2021-04-07 16:10:14.668914: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Downloading https://github.com/ultralytics/yolov5/releases/download/v4.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 113MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7063542 parameters, 7063542 gradients, 16.4 GFLOPS
#
# Transferred 356/362 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 62 .bias, 62 conv.weight, 59 other
# train: Scanning '../cat_and_dog_train_data/labels/train' images and labels... 40 found, 0 missing, 0 empty, 0 corrupted: 100% 40/40 [00:00<00:00, 1314.16it/s]
# train: New cache created: ../cat_and_dog_train_data/labels/train.cache
# train: Caching images (0.0GB): 100% 40/40 [00:00<00:00, 313.66it/s]
# val: Scanning '../cat_and_dog_train_data/labels/val' images and labels... 12 found, 0 missing, 0 empty, 0 corrupted: 100% 12/12 [00:00<00:00, 1086.40it/s]
# val: New cache created: ../cat_and_dog_train_data/labels/val.cache
# val: Caching images (0.0GB): 100% 12/12 [00:00<00:00, 1924.73it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 1.92, Best Possible Recall (BPR) = 1.0000
# Image sizes 640 train, 640 test
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 60 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       0/59     1.78G   0.08177   0.02964         0    0.1114        29       640: 100% 3/3 [00:05<00:00,  1.81s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.22s/it]
#                  all          12          12     0.00167      0.0833    0.000696    0.000172
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       1/59     3.17G   0.09505   0.02755         0    0.1226        16       640: 100% 3/3 [00:00<00:00,  5.31it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  2.99it/s]
#                  all          12          12     0.00227       0.167    0.000962    0.000187
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       2/59     3.17G   0.07939   0.02748         0    0.1069        18       640: 100% 3/3 [00:00<00:00,  5.34it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.00it/s]
#                  all          12          12     0.00259         0.5     0.00139    0.000338
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       3/59     3.17G   0.07932   0.02821         0    0.1075        24       640: 100% 3/3 [00:00<00:00,  5.37it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.26it/s]
#                  all          12          12     0.00324       0.333     0.00232    0.000454
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       4/59     3.17G   0.07621   0.02634         0    0.1026        19       640: 100% 3/3 [00:00<00:00,  5.14it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.12it/s]
#                  all          12          12     0.00391       0.583     0.00258    0.000624
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       5/59     3.17G   0.07296   0.02614         0   0.09911        18       640: 100% 3/3 [00:00<00:00,  5.25it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.31it/s]
#                  all          12          12     0.00504       0.417     0.00378    0.000796
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       6/59     3.17G   0.07201    0.0265         0   0.09851        26       640: 100% 3/3 [00:00<00:00,  5.05it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.33it/s]
#                  all          12          12      0.0158      0.0833     0.00722     0.00127
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       7/59     3.17G   0.06684   0.02636         0    0.0932        24       640: 100% 3/3 [00:00<00:00,  5.19it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.54it/s]
#                  all          12          12      0.0194      0.0833     0.00932     0.00173
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       8/59     3.17G   0.05875    0.0296         0   0.08835        29       640: 100% 3/3 [00:00<00:00,  5.22it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.42it/s]
#                  all          12          12      0.0196      0.0833      0.0122     0.00208
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       9/59     3.17G   0.05853   0.02787         0    0.0864        24       640: 100% 3/3 [00:00<00:00,  5.24it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.64it/s]
#                  all          12          12      0.0218       0.167      0.0141     0.00267
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      10/59     3.17G   0.05829   0.02794         0   0.08623        23       640: 100% 3/3 [00:00<00:00,  5.31it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.80it/s]
#                  all          12          12       0.142      0.0833      0.0341     0.00529
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      11/59     3.17G   0.05633   0.02803         0   0.08436        23       640: 100% 3/3 [00:00<00:00,  5.01it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.99it/s]
#                  all          12          12       0.115        0.25      0.0494     0.00887
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      12/59     3.17G   0.05472    0.0293         0   0.08402        22       640: 100% 3/3 [00:00<00:00,  5.16it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.81it/s]
#                  all          12          12       0.197       0.167      0.0568      0.0123
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      13/59     3.17G   0.07151   0.02997         0    0.1015        29       640: 100% 3/3 [00:00<00:00,  5.11it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.93it/s]
#                  all          12          12       0.191       0.167      0.0636      0.0137
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      14/59     3.17G    0.0546   0.02879         0   0.08339        26       640: 100% 3/3 [00:00<00:00,  5.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.95it/s]
#                  all          12          12       0.183       0.333      0.0869      0.0219
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      15/59     3.17G     0.046   0.02804         0   0.07404        25       640: 100% 3/3 [00:00<00:00,  5.14it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.02it/s]
#                  all          12          12       0.247       0.411       0.135      0.0261
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      16/59     3.17G    0.0462   0.02782         0   0.07403        18       640: 100% 3/3 [00:00<00:00,  5.32it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.24it/s]
#                  all          12          12       0.272       0.333       0.204      0.0654
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      17/59     3.17G   0.04918   0.02454         0   0.07372        19       640: 100% 3/3 [00:00<00:00,  5.31it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.53it/s]
#                  all          12          12       0.176         0.5       0.187      0.0842
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      18/59     3.17G      0.05   0.02883         0   0.07884        23       640: 100% 3/3 [00:00<00:00,  5.09it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.58it/s]
#                  all          12          12       0.223       0.576       0.247      0.0884
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      19/59     3.17G   0.03833   0.02571         0   0.06403        17       640: 100% 3/3 [00:00<00:00,  5.15it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.12it/s]
#                  all          12          12       0.366       0.417       0.347       0.123
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      20/59     3.17G   0.04228   0.02942         0   0.07169        27       640: 100% 3/3 [00:00<00:00,  5.11it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.78it/s]
#                  all          12          12       0.625       0.417       0.448       0.147
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      21/59     3.17G   0.04522   0.02388         0    0.0691        19       640: 100% 3/3 [00:00<00:00,  5.25it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.75it/s]
#                  all          12          12       0.709       0.417       0.471       0.188
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      22/59     3.17G   0.04485   0.03178         0   0.07662        25       640: 100% 3/3 [00:00<00:00,  5.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.58it/s]
#                  all          12          12       0.666       0.499       0.496       0.235
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      23/59     3.17G   0.04411   0.02899         0    0.0731        24       640: 100% 3/3 [00:00<00:00,  5.10it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.85it/s]
#                  all          12          12        0.66         0.5       0.505       0.239
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      24/59     3.17G   0.04441   0.02699         0   0.07139        23       640: 100% 3/3 [00:00<00:00,  5.27it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.01it/s]
#                  all          12          12       0.663         0.5       0.525       0.245
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      25/59     3.17G    0.0402   0.02752         0   0.06772        25       640: 100% 3/3 [00:00<00:00,  5.16it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  4.81it/s]
#                  all          12          12       0.591         0.5       0.508       0.248
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      26/59     3.17G   0.03988   0.02935         0   0.06923        23       640: 100% 3/3 [00:00<00:00,  5.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.15it/s]
#                  all          12          12       0.598         0.5        0.54       0.282
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      27/59     3.17G   0.03789   0.02882         0   0.06671        22       640: 100% 3/3 [00:00<00:00,  5.34it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.15it/s]
#                  all          12          12       0.747         0.5       0.571       0.256
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      28/59     3.17G   0.03931   0.02956         0   0.06887        24       640: 100% 3/3 [00:00<00:00,  5.11it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.68it/s]
#                  all          12          12       0.721         0.5       0.598         0.3
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      29/59     3.17G   0.03887   0.02863         0    0.0675        25       640: 100% 3/3 [00:00<00:00,  5.03it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.51it/s]
#                  all          12          12       0.856       0.496       0.616       0.297
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      30/59     3.17G   0.03741   0.02799         0    0.0654        23       640: 100% 3/3 [00:00<00:00,  5.33it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.17it/s]
#                  all          12          12       0.852       0.481       0.625       0.294
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      31/59     3.17G   0.03945   0.02412         0   0.06357        19       640: 100% 3/3 [00:00<00:00,  4.13it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.53it/s]
#                  all          12          12       0.719         0.5       0.621       0.304
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      32/59     3.17G   0.03746   0.02497         0   0.06243        24       640: 100% 3/3 [00:00<00:00,  5.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.33it/s]
#                  all          12          12       0.853         0.5       0.635       0.317
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      33/59     3.17G   0.04013   0.02705         0   0.06718        19       640: 100% 3/3 [00:00<00:00,  5.33it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.23it/s]
#                  all          12          12       0.998         0.5       0.642       0.371
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      34/59     3.17G   0.03535   0.02727         0   0.06262        24       640: 100% 3/3 [00:00<00:00,  5.07it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.89it/s]
#                  all          12          12       0.997         0.5       0.703       0.399
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      35/59     3.17G   0.05032    0.0257         0   0.07602        22       640: 100% 3/3 [00:00<00:00,  5.27it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.35it/s]
#                  all          12          12       0.857         0.5       0.653        0.37
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      36/59     3.17G   0.03612   0.02804         0   0.06416        25       640: 100% 3/3 [00:00<00:00,  5.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.10it/s]
#                  all          12          12       0.653         0.5       0.601       0.331
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      37/59     3.17G   0.03657    0.0212         0   0.05776        14       640: 100% 3/3 [00:00<00:00,  5.20it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.85it/s]
#                  all          12          12       0.695       0.583       0.671       0.391
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      38/59     3.17G   0.03982   0.02853         0   0.06835        26       640: 100% 3/3 [00:00<00:00,  5.16it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.98it/s]
#                  all          12          12       0.856         0.5       0.669       0.381
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      39/59     3.17G   0.03095   0.02717         0   0.05812        27       640: 100% 3/3 [00:00<00:00,  5.18it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.72it/s]
#                  all          12          12       0.998         0.5       0.685       0.379
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      40/59     3.17G   0.03054   0.02528         0   0.05583        21       640: 100% 3/3 [00:00<00:00,  5.11it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.44it/s]
#                  all          12          12       0.667       0.666       0.703       0.392
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      41/59     3.17G   0.03512   0.02549         0   0.06061        26       640: 100% 3/3 [00:00<00:00,  5.21it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.58it/s]
#                  all          12          12       0.797       0.667       0.735         0.4
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      42/59     3.17G   0.03687   0.02417         0   0.06104        17       640: 100% 3/3 [00:00<00:00,  5.21it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.09it/s]
#                  all          12          12       0.784       0.667       0.746       0.356
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      43/59     3.17G   0.02962   0.02354         0   0.05315        20       640: 100% 3/3 [00:00<00:00,  5.10it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.75it/s]
#                  all          12          12       0.799       0.664       0.745       0.376
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      44/59     3.17G   0.03247   0.02314         0   0.05561        20       640: 100% 3/3 [00:00<00:00,  5.26it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.04it/s]
#                  all          12          12       0.886       0.667        0.76       0.392
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      45/59     3.17G   0.03225   0.02267         0   0.05492        21       640: 100% 3/3 [00:00<00:00,  4.92it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.92it/s]
#                  all          12          12       0.886       0.667       0.749       0.388
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      46/59     3.17G   0.03014   0.02321         0   0.05334        20       640: 100% 3/3 [00:00<00:00,  4.93it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.00it/s]
#                  all          12          12       0.817       0.744       0.775       0.371
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      47/59     3.17G   0.03096   0.02297         0   0.05393        25       640: 100% 3/3 [00:00<00:00,  5.28it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.97it/s]
#                  all          12          12       0.888       0.667       0.772       0.392
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      48/59     3.17G   0.03176   0.02317         0   0.05493        25       640: 100% 3/3 [00:00<00:00,  5.18it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.31it/s]
#                  all          12          12       0.885       0.667       0.777       0.387
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      49/59     3.17G   0.03782    0.0249         0   0.06271        24       640: 100% 3/3 [00:00<00:00,  5.17it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.62it/s]
#                  all          12          12         0.9       0.747       0.767       0.388
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      50/59     3.17G   0.03073   0.02433         0   0.05507        24       640: 100% 3/3 [00:00<00:00,  5.12it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.05it/s]
#                  all          12          12       0.886        0.75       0.769       0.441
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      51/59     3.17G   0.04061   0.01939         0      0.06        18       640: 100% 3/3 [00:00<00:00,  5.26it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.32it/s]
#                  all          12          12       0.818        0.75         0.8        0.43
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      52/59     3.17G   0.02894   0.02328         0   0.05222        24       640: 100% 3/3 [00:00<00:00,  5.24it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  5.83it/s]
#                  all          12          12       0.817        0.75       0.797       0.418
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      53/59     3.17G   0.03371    0.0231         0   0.05681        26       640: 100% 3/3 [00:00<00:00,  5.13it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.04it/s]
#                  all          12          12       0.818        0.75        0.79       0.458
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      54/59     3.17G   0.03298   0.02028         0   0.05325        19       640: 100% 3/3 [00:00<00:00,  5.11it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  7.13it/s]
#                  all          12          12       0.818        0.75       0.789       0.448
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      55/59     3.17G   0.03135   0.02156         0   0.05291        27       640: 100% 3/3 [00:00<00:00,  5.50it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.46it/s]
#                  all          12          12       0.817        0.75       0.791       0.438
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      56/59     3.17G   0.03045   0.02297         0   0.05342        26       640: 100% 3/3 [00:00<00:00,  5.24it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.13it/s]
#                  all          12          12       0.817        0.75       0.795       0.426
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      57/59     3.17G   0.02686   0.02275         0   0.04961        24       640: 100% 3/3 [00:00<00:00,  5.70it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.77it/s]
#                  all          12          12       0.748        0.75       0.778        0.45
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      58/59     3.17G   0.02688   0.02034         0   0.04722        20       640: 100% 3/3 [00:00<00:00,  5.10it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  6.84it/s]
#                  all          12          12       0.816        0.75       0.797       0.462
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      59/59     3.17G   0.04105   0.02384         0   0.06489        24       640: 100% 3/3 [00:00<00:00,  5.70it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 1/1 [00:00<00:00,  3.54it/s]
#                  all          12          12       0.816        0.75       0.797       0.458
# 60 epochs completed in 0.016 hours.
#
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.4MB

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <img src="https://user-images.githubusercontent.com/26833433/98184457-bd3da580-1f0a-11eb-8461-95d908a71893.jpg" width="800">

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and test jpgs to see mosaics, labels, predictions and augmentation effects. Note a **Mosaic Dataloader** is used for training (shown below), a new concept developed by Ultralytics and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
Image(filename='runs/train/exp/train_batch0.jpg', width=800)  # train batch 0 mosaics and labels
Image(filename='runs/train/exp/test_batch0_labels.jpg', width=800)  # test batch 0 labels
Image(filename='runs/train/exp/test_batch0_pred.jpg', width=800)  # test batch 0 predictions

# %% [markdown]
# > <img src="https://user-images.githubusercontent.com/26833433/83667642-90fcb200-a583-11ea-8fa3-338bbf7da194.jpeg" width="750">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/83667626-8c37fe00-a583-11ea-997b-0923fe59b29b.jpeg" width="750">
# `test_batch0_labels.jpg` shows test batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/83667635-90641b80-a583-11ea-8075-606316cebb9c.jpeg" width="750">
# `test_batch0_pred.jpg` shows test batch 0 _predictions_

# %% [markdown]
# Training losses and performance metrics are also logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and a custom `results.txt` logfile which is plotted as `results.png` (below) after training completes. Here we show YOLOv5s trained on COCO128 to 300 epochs, starting from scratch (blue), and from pretrained `--weights yolov5s.pt` (orange).

# %%
from utils.plots import plot_results 
plot_results(save_dir='runs/train/exp')  # plot all results*.txt as results.png
Image(filename='runs/train/exp/results.png', width=800)

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/26833433/97808309-8182b180-1c66-11eb-8461-bffe1a79511d.png" width="800">

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([test.py](https://github.com/ultralytics/yolov5/blob/master/test.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/models/export.py)) on MacOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Re-clone repo
# %cd ..
# %rm -rf yolov5 && git clone https://github.com/ultralytics/yolov5
# %cd yolov5

# %%
# Reproduce
for x in 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python test.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.25 --iou 0.45  # speed
  # !python test.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://github.com/ultralytics/yolov5/raw/master/data/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# Unit tests
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories

rm -rf runs  # remove runs/
for m in yolov5s; do  # models
  python train.py --weights $m.pt --epochs 3 --img 320 --device 0  # train pretrained
  python train.py --weights '' --cfg $m.yaml --epochs 3 --img 320 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
    python test.py --weights $m.pt --device $d # test official
    python test.py --weights runs/train/exp/weights/best.pt --device $d # test custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # inspect
  python models/export.py --weights $m.pt --img 640 --batch 1  # export
done

# %%
# Profile
from utils.torch_utils import profile 

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
profile(x=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 48, 32, 16], ['yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # zip(batch_size, model)
  # !python train.py --batch {b} --weights {m}.pt --data voc.yaml --epochs 50 --cache --img 512 --nosave --hyp hyp.finetune.yaml --project VOC --name {m}
